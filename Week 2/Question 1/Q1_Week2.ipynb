# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def show_images(images, titles, cmap=None):
    """Plots multiple images in a single row."""
    n = len(images)
    plt.figure(figsize=(15, 5))
    for i in range(n):
        plt.subplot(1, n, i + 1)
        plt.imshow(images[i], cmap=cmap)
        plt.title(titles[i])
        plt.axis('off')
    plt.show()

# %%
def display_details(path):
    image_path = path
    original_img = cv2.imread(image_path)
    
    if original_img is None:
        print(f"Error: Could not load image -> {image_path}.")
    else:
        original_rgb = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)
        gray_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2GRAY)
        
        show_images([original_rgb, gray_img], ['Original Image', 'Grayscale Image'], cmap='gray')
    
        plt.figure(figsize=(8, 4))
        plt.hist(gray_img.ravel(), bins=256, range=[0, 256], color='gray', alpha=0.7)
        plt.title('Grayscale Pixel Intensity Histogram')
        plt.xlabel('Pixel Intensity (0=Black, 255=White)')
        plt.ylabel('Number of Pixels')
        plt.show()
    
        resized_img = cv2.resize(gray_img, (256, 256))
        
        print(f"Original Shape: {gray_img.shape} | Resized Shape: {resized_img.shape}")
    
        edges = cv2.Canny(gray_img, 100, 200)
        
        show_images([gray_img, edges], ['Grayscale', 'Canny Edge Detection'], cmap='gray')
    
        row, col = gray_img.shape
        mean = 0
        sigma = 25 # Adjust sigma to increase/decrease noise
        gauss_noise = np.random.normal(mean, sigma, (row, col))
        
        noisy_img = np.zeros(gray_img.shape, np.float32)
        noisy_img = gray_img + gauss_noise
        noisy_img = np.clip(noisy_img, 0, 255).astype(np.uint8) # Keep values valid between 0-255
    
        denoised_img = cv2.GaussianBlur(noisy_img, (5, 5), 0)
        
        show_images([noisy_img, denoised_img], ['Image with Added Noise', 'Noise Removed (Gaussian Filter)'], cmap='gray')

# %%
image_1="image1.jpeg"
display_details(image_1)

# %%
image_2="image2.jpg"
display_details(image_2)
